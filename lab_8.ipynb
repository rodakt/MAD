# %% [markdown]
# # Modele analizy danych
#
# Tomasz Rodak
#
# ---

# %% [markdown]
# ### Zadanie 8.1
#
# Rozwiąż zadania 4.8.1, 4.8.4, 4.8.6, 4.8.7, 4.8.8, 4.8.9 z [ISLP](https://www.statlearning.com/).
#
# ---

# %% [markdown]
# ### Zadanie 8.2
#
# Rozwiąż zadania 4.8.13, 4.8.14, 4.8.16 z [ISLP](https://www.statlearning.com/).
#
# ---
