# %% [markdown]
# # Modele analizy danych
#
# ### 2024/2025, semestr zimowy
# Tomasz Rodak
#
# ---

# %% [markdown]
# ### Zadanie 11.1
#
# Dane z wykładu 10:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_moons

# %%
n = 2000
X, y = make_moons(n_samples=n, noise=.5, random_state=0)
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, alpha=.5);

# %% [markdown]
# Przeprowadź selekcję hiperparametru `k` w modelu k-NN dla tego zbioru danych.
# 1. Zbiór danych podziel na zbiór treningowy i testowy.
# 2. Wykorzystaj Optunę do automatycznej optymalizacji hiperparametru `k`. Jakość modelu oceniaj na podstawie dokładności klasyfikacji (accuracy) wyliczanej w procesie walidacji krzyżowej.
# 3. Wytrenuj najlepszy model na całym zbiorze treningowym i oceń jego skuteczność na zbiorze testowym, obliczając dokładność klasyfikacji i macierz pomyłek.
# 4. Narysuj wykres rozrzutu danych, zaznaczając punkty z różnych klas oraz granicę decyzyjną wytrenowanego modelu.

# %% [markdown]
# ### Zadanie 11.2
#
# Rozwiąż zadanie 11.1, ale tym razem poza k-NN wykorzystaj również pozostałe modele klasyfikacyjne omówione na poprzednich wykładach.
